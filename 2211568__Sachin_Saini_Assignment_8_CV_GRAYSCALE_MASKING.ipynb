# %% [markdown]
# ### IMPORT ALL THE NECESSARY LIBRARIES

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %% [markdown]
# ### READ THE IMAGE AND DISPLAY IT

# %%
image_color=mpimg.imread('image_lane_c.jpg')

# %%
image_color.shape
# Out:
# (540, 960, 3)

# %%
plt.imshow(image_color)

# %% [markdown]
# Convert the image to grayscale

# %%
image_gray=cv2.cvtColor(image_color,cv2.COLOR_BGR2GRAY)
plt.imshow(image_gray,cmap='gray')
image_gray.shape
# Out:
# (540, 960)

# %% [markdown]
# ### Let's sort out the white color out of the image

# %%
image_copy=np.copy(image_gray)
image_copy.shape
# Out:
# (540, 960)

# %%
image_copy[(image_copy[:,:]<250)]=0
#any value that is not white color is removed

# %%
#display the image 
plt.imshow(image_copy,cmap='gray')
plt.show()

# %%
image_copy=np.copy(image_color)
image_copy.shape
# Out:
# (540, 960, 3)

# %%
image_copy[(image_copy[:,:,0]<250)|(image_copy[:,:,1]<200)|(image_copy[:,:,2]<200)]=0

# %%
plt.imshow(image_copy,cmap='gray')
plt.show()

# %% [markdown]
# **REGION OF INTEREST SELECTION**

# %%
import cv2
import numpy as np
import matplotlib.image as mpimg
from matplotlib import pyplot as plt
# %matplotlib inline
from google.colab.patches import cv2_imshow

# %%
image_color=cv2.imread('image_lane_c.jpg')

# %%
from google.colab.patches import cv2_imshow
cv2.imshow('Original Image',image_color)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# DisabledFunctionError                     Traceback (most recent call last)
# <ipython-input-14-be2b1fb47cee> in <module>
#       1 from google.colab.patches import cv2_imshow
# ----> 2 cv2.imshow('Original Image',image_color)
#       3 cv2.waitKey()
#       4 cv2.destroyAllWindows()
#
# /usr/local/lib/python3.7/dist-packages/google/colab/_import_hooks/_cv2.py in wrapped(*args, **kwargs)
#      46   def wrapped(*args, **kwargs):
#      47     if not os.environ.get(env_var, False):
# ---> 48       raise DisabledFunctionError(message, name or func.__name__)
#      49     return func(*args, **kwargs)
#      50
#
# DisabledFunctionError: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow

# %%
height,width,channels=image_color.shape
channels
# Out:
# 3

# %%
height,width=image_color.shape[:2]

# %%
height
# Out:
# 540

# %%
width
# Out:
# 960

# %%
plt.imshow(image_color)

# %%
image_color.shape
# Out:
# (540, 960, 3)

# %% [markdown]
# ### **CONVERT TO GRAYSCALE**

# %%
image_gray=cv2.cvtColor(image_color,cv2.COLOR_BGR2GRAY)
plt.imshow(image_gray,cmap='gray')

# %%
image_gray.shape
# Out:
# (540, 960)

# %% [markdown]
# ### **PERFORMING REGION OF INTEREST MASKING**

# %%
# Select points of the region of interest (ROI)
ROI = np.array([[(0, height),(400, 330), (550, 330), (width, height)]], dtype=np.int32)    
 
# define a blank image with all zeros (ie: black) 
blank = np.zeros_like(image_gray)

# %%
blank.shape
# Out:
# (540, 960)

# %%
# Fill the Region of interest with white color (ie: 255)!
mask = cv2.fillPoly(blank, ROI, 255)

# Perform bitwise AND operation to select only the region of interest
masked_image = cv2.bitwise_and(image_gray, mask)

# %%
masked_image.shape
# Out:
# (540, 960)

# %%
plt.imshow(masked_image,cmap='gray')
